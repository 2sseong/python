# %% [markdown]
# # 외부 라이브러리

# %% [markdown]
# ## pip *

# %% [raw]
# [WSL] 관리자권한으로 실행할것
# (업데이트설치)
# wsl.exe --install
#
# (확인시)
# wsl -l -v
#
# (삭제시)
# wsl --unregister Ubuntu-22.04
# wsl --shutdown
# =================
# /home/ys
#
# 1) sudo apt update
# 2) sudo apt upgrade -y
# 3) python3 -V
#
# ====================
# [그외 트러블 슈팅]
# wsl 버전올리기:
# wsl --set-default-version 2
# wsl --update
# wsl -l -v
#
# 해당 파일 버전업하기:
# wsl --set-version Ubuntu-22.04 2
#
# 초기화:
# wsl --unregister Ubuntu-22.04
# wsl --install -d Ubuntu-22.04
# ==========================
# [Ubuntu명령어]
# pwd: 현재경로확인 (~ 표시된 경로는 기본 사용자 경로)
# Ctrl + c: 캔슬
#
# su: 루트권한
# sudo: 이 순간만 관리자 권한 실행
# sudo passwd: 관리자 권한 비밀번호 세팅
# exit: 빠져나가기
# ls -al: 리스트 상세
# lshw: 하드웨어 정보
# lsusb: usb정보
# htop: 프로세서 현황 확인
# cd: 디렉토리 이동
# ----------------------------------------------------------
# mkdir: 디렉토리 생성
# rm: 파일또는 디렉토리 삭제 ex) rm 파일명
#      rm -r 폴더명
#      rm -rf 폴더명(강력함)
# echo "하고싶은말"
# echo "하고싶은말" > 파일명.txt(파일로저장됨)
# cat 파일명.txt(내용 읽어오기)
# cat > 파일명.txt('w' 새로 작성하기)
# cat >> 파일명.txt ('a'추가하기)
# cat <<'end'> diary.txt
# -------------------------------------------------------------
# vi(vim): 힘들어
# nano: 편집기
# .bashrc: 유저의 환경설정파일
# sudo apt install cowsay: cowsay설치
# sudo apt remove cowsay: cowsay제거
# ssh 설치: sudo apt install openssh-server
# sudo systemctl status ssh
# sudo systemctl start ssh
# sudo systemctl stop ssh
#
# sudo apt install net-tools
# ifconfig: 아이피 확인
#
# ssh sh@localhost
# ssh sh@아이피로 접속
#
#
# Ctrl + shift + w: 터미널 닫기
# Alt + shift + '+' or '-': 세로 가로 분할
# ---------------------------------------------------------
# sudo apt update
# sudo apt install mysql-server
# sudo systemctl status mysql
# sudo systemctl stop mysql
# sud apt remove mysql-server
#
# 윈도우 + 추가 파이썬 // 우분투에는 이미 있는 파이썬
#
# sudo apt install python3-pip
# pip3 install jupyterlab
# sudo apt install jupyter-core
#
# 파이썬 가상공간 실행
# sudo apt install python3-venv
# python3 -m venv venv -> 폴더와 가상시스템이 생성됨
#
# 가상사용: source ./venv/bin/activate
# 나가기: deactivate
# 삭제: sudo rm -rf venv
#
# 백업: pip freeze > requirements.txt
# 복구: pip install -r requirements.txt
#
# nano requirements.txt  ->numpy 2.2.0변경
# cat require* 확인

# %% [markdown]
# ## Faker

# %%
# !pip install Faker

# %%
from faker import Faker
fake = Faker('ko-KR')
fake.name()
[{'name':fake.name(), 'id':fake.user_name(), 'phone':fake.phone_number(),'email':fake.email()} for n in range(10)]
# Out:
# [{'name': '권혜진',
#   'id': 'sangceol49',
#   'phone': '064-708-0339',
#   'email': 'egim@example.com'},
#  {'name': '강보람',
#   'id': 'uryu',
#   'phone': '033-455-9739',
#   'email': 'qsong@example.org'},
#  {'name': '김경수',
#   'id': 'mbag',
#   'phone': '019-179-1257',
#   'email': 'qbag@example.com'},
#  {'name': '배보람',
#   'id': 'jeonghun48',
#   'phone': '019-218-1681',
#   'email': 'sonseoyun@example.com'},
#  {'name': '박정수',
#   'id': 'hyeonjuhan',
#   'phone': '041-822-2793',
#   'email': 'lryu@example.org'},
#  {'name': '이성호',
#   'id': 'jiweon51',
#   'phone': '042-536-5193',
#   'email': 'jimin66@example.org'},
#  {'name': '이예원',
#   'id': 'yeeun31',
#   'phone': '031-334-0422',
#   'email': 'ansiu@example.org'},
#  {'name': '고준영',
#   'id': 'ogsun00',
#   'phone': '019-689-6455',
#   'email': 'seonyeonggim@example.com'},
#  {'name': '김예진',
#   'id': 'byeongceolsong',
#   'phone': '051-313-6802',
#   'email': 'jbag@example.net'},
#  {'name': '최재현',
#   'id': 'yujingim',
#   'phone': '019-022-3274',
#   'email': 'gimseongmin@example.org'}]

# %% [markdown]
# <table style='float:left;width:400px'>
# <thead>
# <tr>
# <th>항목</th>
# <th>설명</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>fake.name()</td>
# <td>이름</td>
# </tr>
# <tr>
# <td>fake.address()</td>
# <td>주소</td>
# </tr>
# <tr>
# <td>fake.postcode()</td>
# <td>우편 번호</td>
# </tr>
# <tr>
# <td>fake.country()</td>
# <td>국가명</td>
# </tr>
# <tr>
# <td>fake.company()</td>
# <td>회사명</td>
# </tr>
# <tr>
# <td>fake.job()</td>
# <td>직업명</td>
# </tr>
# <tr>
# <td>fake.phone_number()</td>
# <td>휴대전화 번호</td>
# </tr>
# <tr>
# <td>fake.email()</td>
# <td>이메일 주소</td>
# </tr>
# <tr>
# <td>fake.user_name()</td>
# <td>사용자명</td>
# </tr>
# <tr>
# <td>fake.pyint(min_value=0, max_value=100)</td>
# <td>0부터 100 사이의 임의의 숫자</td>
# </tr>
# <tr>
# <td>fake.ipv4_private()</td>
# <td>IP 주소</td>
# </tr>
# <tr>
# <td>fake.text()</td>
# <td>임의의 문장 (한글 임의의 문장은 <code>fake.catch_phrase()</code> 사용)</td>
# </tr>
# <tr>
# <td>fake.color_name()</td>
# <td>색상명</td>
# </tr>
# </tbody>
#
#  </table>

# %%
import requests as req
from bs4 import BeautifulSoup as bs
url='https://www.melon.com/chart/index.htm'
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36 Edg/133.0.0.0'}
web = req.get(url, headers = headers)
soup = bs(web.content, 'html.parser')

# title = soup.select_one('.wrap_song_info')
# atitle = title.select_one('a')



# name = title.select_one('.checkEllipsis')
# aname = name.select_one('a')
# print('1위:',atitle.text,'/',aname.text)


title = soup.select('.wrap_song_info .rank01')
name = soup.select('div.ellipsis.rank02 span')

for i, (t, n) in enumerate(zip(title,name),1):
    str = f'{i}위: {t.text.strip()} / {n.text}'
    print(str)
# Out:
# 1위: REBEL HEART / IVE (아이브)
# 2위: HOME SWEET HOME (feat. 태양, 대성) / G-DRAGON
# 3위: 나는 반딧불 / 황가람
# 4위: Whiplash / aespa
# 5위: APT. / 로제 (ROSÉ), Bruno Mars
# 6위: Drowning / WOODZ
# 7위: ATTITUDE / IVE (아이브)
# 8위: 오늘만 I LOVE YOU / BOYNEXTDOOR
# 9위: Dash / PLAVE
# 10위: toxic till the end / 로제 (ROSÉ)
# 11위: 모르시나요(PROD.로코베리) / 조째즈
# 12위: POWER / G-DRAGON
# 13위: RIZZ / PLAVE
# 14위: HAPPY / DAY6 (데이식스)
# 15위: Chroma Drift / PLAVE
# 16위: 내게 사랑이 뭐냐고 물어본다면 / 로이킴
# 17위: Island / PLAVE
# 18위: 12:32 (A to T) / PLAVE
# 19위: 사랑은 늘 도망가 / 임영웅
# 20위: DRIP / BABYMONSTER
# 21위: 소나기 / 이클립스 (ECLIPSE)
# 22위: 너와의 모든 지금 / 재쓰비 (JAESSBEE)
# 23위: Supernova / aespa
# 24위: 천상연 / 이창섭
# 25위: Welcome to the Show / DAY6 (데이식스)
# 26위: 우리들의 블루스 / 임영웅
# 27위: 온기 / 임영웅
# 28위: 한 페이지가 될 수 있게 / DAY6 (데이식스)
# 29위: UP (KARINA Solo) / aespa
# 30위: 내 이름 맑음 / QWER
# 31위: Home / 임영웅
# 32위: 슬픈 초대장 / 순순희(지환)
# 33위: 모래 알갱이 / 임영웅
# 34위: 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지 / AKMU (악뮤)
# 35위: 다시 만날 수 있을까 / 임영웅
# 36위: 이제 나만 믿어요 / 임영웅
# 37위: Love wins all / 아이유
# 38위: Do or Die / 임영웅
# 39위: 무지개 / 임영웅
# 40위: 고민중독 / QWER
# 41위: London Boy / 임영웅
# 42위: 예뻤어 / DAY6 (데이식스)
# 43위: Mantra / 제니 (JENNIE)
# 44위: Die With A Smile / Lady Gaga, Bruno Mars
# 45위: 인생찬가 / 임영웅
# 46위: Polaroid / 임영웅
# 47위: How Sweet / NewJeans
# 48위: 너의 모든 순간 / 성시경
# 49위: 첫 만남은 계획대로 되지 않아 / TWS (투어스)
# 50위: 나는 아픈 건 딱 질색이니까 / (여자)아이들
# 51위: 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection)) / 너드커넥션 (Nerd Connection)
# 52위: 미치게 그리워서 / 황가람
# 53위: 연애편지 / 임영웅
# 54위: Supersonic / 프로미스나인
# 55위: 무제(無題) (Untitled, 2014) / G-DRAGON
# 56위: I AM / IVE (아이브)
# 57위: 비의 랩소디 / 임재현
# 58위: 에피소드 / 이무진
# 59위: Small girl (feat. 도경수(D.O.)) / 이영지
# 60위: 미안해 미워해 사랑해 / Crush
# 61위: 모든 날, 모든 순간 (Every day, Every Moment) / 폴킴
# 62위: 보금자리 / 임영웅
# 63위: 청춘만화 / 이무진
# 64위: 헤어지자 말해요 / 박재정
# 65위: 다정히 내 이름을 부르면 / 경서예지, 전건호
# 66위: number one girl / 로제 (ROSÉ)
# 67위: Magnetic / 아일릿(ILLIT)
# 68위: 청혼하지 않을 이유를 못 찾았어 / 이무진
# 69위: 살기 위해서 / 순순희
# 70위: Ditto / NewJeans
# 71위: 인사 / 범진
# 72위: Hype Boy / NewJeans
# 73위: Armageddon / aespa
# 74위: 해야 (HEYA) / IVE (아이브)
# 75위: 주저하는 연인들을 위해 / 잔나비
# 76위: 사랑인가 봐 / 멜로망스
# 77위: Seven (feat. Latto) - Clean Ver. / 정국
# 78위: Igloo / KISS OF LIFE
# 79위: Hug (포옹) / RIIZE
# 80위: 취중고백 / 김민석
# 81위: 눈이 오잖아(Feat.헤이즈) / 이무진
# 82위: Supernatural / NewJeans
# 83위: 청바지 / 부석순 (SEVENTEEN)
# 84위: Sticky / KISS OF LIFE
# 85위: 클락션 (Klaxon) / (여자)아이들
# 86위: 녹아내려요 / DAY6 (데이식스)
# 87위: To. X / 태연 (TAEYEON)
# 88위: Love 119 / RIIZE
# 89위: earthquake / 지수 (JISOO)
# 90위: 사막에서 꽃을 피우듯 / 우디 (Woody)
# 91위: 봄여름가을겨울 (Still Life) / BIGBANG (빅뱅)
# 92위: Boom Boom Bass / RIIZE
# 93위: SPOT! (feat. JENNIE) / 지코 (ZICO)
# 94위: 사건의 지평선 / 윤하 (YOUNHA)
# 95위: 봄날 / 방탄소년단
# 96위: 첫 눈 / EXO
# 97위: Dynamite / 방탄소년단
# 98위: Bubble Gum / NewJeans
# 99위: Congratulations / DAY6 (데이식스)
# 100위: Drama / aespa

# %%
import melon
melon.mel()
# Out:
# 1위: REBEL HEART / IVE (아이브)
# 2위: HOME SWEET HOME (feat. 태양, 대성) / G-DRAGON
# 3위: 나는 반딧불 / 황가람
# 4위: Whiplash / aespa
# 5위: Drowning / WOODZ
# 6위: ATTITUDE / IVE (아이브)
# 7위: APT. / 로제 (ROSÉ)
# 8위: 오늘만 I LOVE YOU / Bruno Mars
# 9위: toxic till the end / BOYNEXTDOOR
# 10위: 모르시나요(PROD.로코베리) / 로제 (ROSÉ)
# 11위: Dash / 조째즈
# 12위: HAPPY / PLAVE
# 13위: POWER / DAY6 (데이식스)
# 14위: 내게 사랑이 뭐냐고 물어본다면 / G-DRAGON
# 15위: RIZZ / 로이킴
# 16위: DRIP / PLAVE
# 17위: Chroma Drift / BABYMONSTER
# 18위: Island / PLAVE
# 19위: 너와의 모든 지금 / PLAVE
# 20위: 소나기 / 재쓰비 (JAESSBEE)

# %%
import requests as req
from bs4 import BeautifulSoup as bs
url = 'https://finance.naver.com/sise/sise_market_sum.naver'

web = req.get(url)
soup = bs(web.content, 'html.parser')
title = soup.select('.tltle')
price = soup.select( '.no+td+td')
total = soup.select( '#contentarea > div.box_type_l > table.type_2 > tbody > tr > td:nth-child(7)') 



for i, (t,p,tt) in enumerate(zip(title,price,total),1):
    print(f'no.{i}:{t.text}\n현재가: {p.text} /시가총액: {tt.text}')

    #contentarea > div.box_type_l > table.type_2 > tbody > tr > td:nth-child(7)    #시가총액
    #contentarea > div.box_type_l > table.type_2 > tbody > tr:nth-child(2) > td:nth-child(7)
    #contentarea > div.box_type_l > table.type_2 > tbody > tr > td:nth-child(3)    #현재가
    #contentarea > div.box_type_l > table.type_2 > tbody > tr:nth-child(2) > td:nth-child(3)
# Out:
# no.1:삼성전자
# 현재가: 58,400 /시가총액: 3,486,353
# no.2:SK하이닉스
# 현재가: 212,500 /시가총액: 1,547,005
# no.3:LG에너지솔루션
# 현재가: 375,500 /시가총액: 878,670
# no.4:삼성바이오로직스
# 현재가: 1,142,000 /시가총액: 812,807
# no.5:현대차
# 현재가: 201,500 /시가총액: 421,974
# no.6:삼성전자우
# 현재가: 49,450 /시가총액: 406,917
# no.7:셀트리온
# 현재가: 180,600 /시가총액: 386,679
# no.8:기아
# 현재가: 93,900 /시가총액: 373,415
# no.9:NAVER
# 현재가: 220,500 /시가총액: 349,354
# no.10:KB금융
# 현재가: 82,700 /시가총액: 325,448
# no.11:한화에어로스페이스
# 현재가: 649,000 /시가총액: 295,822
# no.12:HD현대중공업
# 현재가: 311,500 /시가총액: 276,528
# no.13:신한지주
# 현재가: 47,450 /시가총액: 238,885
# no.14:삼성물산
# 현재가: 132,700 /시가총액: 235,920
# no.15:현대모비스
# 현재가: 252,500 /시가총액: 234,813
# no.16:메리츠금융지주
# 현재가: 123,000 /시가총액: 234,586
# no.17:한화오션
# 현재가: 74,000 /시가총액: 226,746
# no.18:POSCO홀딩스
# 현재가: 270,000 /시가총액: 223,086
# no.19:삼성생명
# 현재가: 99,600 /시가총액: 199,200
# no.20:SK이노베이션
# 현재가: 130,800 /시가총액: 197,553
# no.21:삼성화재
# 현재가: 400,500 /시가총액: 189,736
# no.22:두산에너빌리티
# 현재가: 28,550 /시가총액: 182,880
# no.23:하나금융지주
# 현재가: 62,200 /시가총액: 178,664
# no.24:카카오
# 현재가: 39,700 /시가총액: 176,139
# no.25:LG화학
# 현재가: 246,500 /시가총액: 174,010
# no.26:고려아연
# 현재가: 824,000 /시가총액: 170,595
# no.27:HMM
# 현재가: 18,610 /시가총액: 163,961
# no.28:크래프톤
# 현재가: 332,000 /시가총액: 159,053
# no.29:삼성SDI
# 현재가: 226,500 /시가총액: 155,752
# no.30:HD한국조선해양
# 현재가: 218,000 /시가총액: 154,285
# no.31:한국전력
# 현재가: 21,600 /시가총액: 138,664
# no.32:LG전자
# 현재가: 82,600 /시가총액: 135,173
# no.33:SK스퀘어
# 현재가: 100,800 /시가총액: 134,616
# no.34:HD현대일렉트릭
# 현재가: 371,000 /시가총액: 133,735
# no.35:KT&G
# 현재가: 105,300 /시가총액: 132,007
# no.36:우리금융지주
# 현재가: 17,330 /시가총액: 128,691
# no.37:SK텔레콤
# 현재가: 58,800 /시가총액: 126,297
# no.38:기업은행
# 현재가: 15,570 /시가총액: 124,159
# no.39:삼성중공업
# 현재가: 13,740 /시가총액: 120,912
# no.40:KT
# 현재가: 47,350 /시가총액: 119,332
# no.41:카카오뱅크
# 현재가: 23,850 /시가총액: 113,759
# no.42:LG
# 현재가: 70,000 /시가총액: 110,111
# no.43:포스코퓨처엠
# 현재가: 141,800 /시가총액: 109,843
# no.44:SK
# 현재가: 148,700 /시가총액: 107,812
# no.45:삼성전기
# 현재가: 143,100 /시가총액: 106,887
# no.46:하이브
# 현재가: 248,000 /시가총액: 103,297
# no.47:한미반도체
# 현재가: 106,500 /시가총액: 102,894
# no.48:삼성에스디에스
# 현재가: 129,700 /시가총액: 100,359
# no.49:유한양행
# 현재가: 122,500 /시가총액: 98,256
# no.50:현대글로비스
# 현재가: 129,300 /시가총액: 96,975

# %%
# !pip install html5lib

# %%
import requests as req
from bs4 import BeautifulSoup as bs
url = 'https://www.pusan.ac.kr/kor/CMS/MenuMgr/menuListOnBuilding.do?mCode=MN202'
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/133.0.0.0 Safari/537.36 Edg/133.0.0.0'}
web = req.get(url, headers = headers)
soup = bs(web.content, 'html5lib')
menucard = soup.select('.menu-tbl')
won = soup.select('.menu-tit01')
menu = soup.select('h3.menu-tit01+p')
day = soup.select('.day')
date = soup.select('.date')
# test = soup.select('.#cont > div.menu-wr > div.wauto-wrap > div.is-wauto-box.menu-tbl-wr > table > tbody > tr:nth-child(2) > td:nth-child(2) > ul > li > p')
for d,dd,w,m in zip(day,date,won,menu):
    print('='*18)
    print(d.text,dd.text)
    print(w.text+'\n' + m.text)
    
print(menu)
# Out:
# [<div class="day">월</div>, <div class="day">화</div>, <div class="day">수</div>, <div class="day">목</div>, <div class="day">금</div>, <div class="day">토</div>]
# ==================
# 월 2025.02.17
# 정식-5,500원
# 강황밥
# 김치콩나물국
# 돈육바싹불고기
# 모듬잡채
# 멸치새우견과볶음
# 상추겉절이
# 포기김치
#
# ==================
# 화 2025.02.18
# 정식-5,500원
# 백미밥
# 물만두국
# 순살닭매콤조림
# 쫄면야채무침
# 파래무무침
# 참나물겉절이
# 포기김치
#
# ==================
# 수 2025.02.19
# 정식-5,500원
# 백미밥
# 모듬어묵국
# 함박스테이크/치즈/소스
# 스파게티/소스
# 치커리유자청샐러드
# 콩나물무침
# 포기김치
#
# ==================
# 목 2025.02.20
# 정식-5,500원
# 잡곡밥
# 홍합미역국
# 순살치킨/맛초킹소스
# 꼬시레기두부무침
# 잡채어묵조림
# 상추겉절이
# 포기김치
#
# ==================
# 금 2025.02.21
# 정식-5,500원
# 백미밥
# 국수
# 깐풍기/소스
# 알감자버터구이
# 도토리묵김치무침
# 열무겉절이
# 포기김치
#
# [<p>강황밥
# <br/>김치콩나물국
# <br/>돈육바싹불고기
# <br/>모듬잡채
# <br/>멸치새우견과볶음
# <br/>상추겉절이
# <br/>포기김치
# <br/></p>, <p>백미밥
# <br/>물만두국
# <br/>순살닭매콤조림
# <br/>쫄면야채무침
# <br/>파래무무침
# <br/>참나물겉절이
# <br/>포기김치
# <br/></p>, <p>백미밥
# <br/>모듬어묵국
# <br/>함박스테이크/치즈/소스
# <br/>스파게티/소스
# <br/>치커리유자청샐러드
# <br/>콩나물무침
# <br/>포기김치
# <br/></p>, <p>잡곡밥
# <br/>홍합미역국
# <br/>순살치킨/맛초킹소스
# <br/>꼬시레기두부무침
# <br/>잡채어묵조림
# <br/>상추겉절이
# <br/>포기김치
# <br/></p>, <p>백미밥
# <br/>국수
# <br/>깐풍기/소스
# <br/>알감자버터구이
# <br/>도토리묵김치무침
# <br/>열무겉절이
# <br/>포기김치
# <br/></p>]

# %%
import requests as req
from bs4 import BeautifulSoup as bs
def stock():
    url = 'https://finance.naver.com/sise/sise_market_sum.naver'
    
    web = req.get(url)
    soup = bs(web.content, 'html.parser')
    title = soup.select('.tltle')
    price = soup.select( '.no+td+td')
    total = soup.select( '#contentarea > div.box_type_l > table.type_2 > tbody > tr > td:nth-child(7)') 
    
    
    
    for i, (t,p,tt) in enumerate(zip(title,price,total),1):
        print(f'no.{i}:{t.text}\n현재가: {p.text} /시가총액: {tt.text}')

# %%
from team_5.stock_이성훈 import stock_이
print(stock_이성훈.stock())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 from team_5 import stock_이성훈
#       2 print(stock_이성훈.stock())
#
# ImportError: cannot import name 'stock_이성훈' from 'team_5' (unknown location)
