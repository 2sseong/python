# %%
# !pip install folium

# %%
import pandas as pd
import folium
file_path = './starbucks_250411123344.csv'
data = pd.read_csv(file_path)
data = data[['이름','위도','경도','주소','타입']]
data
# Out:
#            이름         위도          경도  \
# 0     금정남산동DT  35.262179  129.091325
# 1      금정구청DT  35.238814  129.092986
# 2      온천장역DT  35.224006  129.086560
# 3       부산대정문  35.232122  129.084496
# 4        부산대역  35.230522  129.088694
# ..        ...        ...         ...
# 139  부산성모안과병원  35.167491  129.140791
# 140   센텀신세계3F  35.169063  129.129066
# 141    해운대중동역  35.167185  129.167886
# 142     센텀몰1F  35.169936  129.128342
# 143  그랜드조선 부산  35.160058  129.163154
#
#                                             주소             타입
# 0           부산광역시 금정구 중앙대로 1989 (남산동)1522-3232  pin_generalDT
# 1           부산광역시 금정구 중앙대로 1730 (부곡동)1522-3232  pin_generalDT
# 2             부산광역시 금정구 식물원로 13 (장전동)1522-3232  pin_generalDT
# 3        부산광역시 금정구 부산대학로64번길 12 (장전동)1522-3232    pin_general
# 4    부산광역시 금정구 장전로12번길 64, 1~4층 (장전동)1522-3232    pin_general
# ..                                         ...            ...
# 139          부산광역시 해운대구 해운대로 409 (우동)1522-3232    pin_general
# 140          부산광역시 해운대구 센텀남대로 35 (우동)1522-3232    pin_general
# 141           부산광역시 해운대구 좌동순환로 6 (중동)1522-3232    pin_general
# 142           부산광역시 해운대구 센텀4로 15 (우동)1522-3232    pin_general
# 143        부산광역시 해운대구 해운대해변로 292 (중동)1522-3232    pin_general
#
# [144 rows x 5 columns]

# %%
fixdata = data[['이름','위도','경도']]
fixdata.head()
# Out:
#         이름         위도          경도
# 0  금정남산동DT  35.262179  129.091325
# 1   금정구청DT  35.238814  129.092986
# 2   온천장역DT  35.224006  129.086560
# 3    부산대정문  35.232122  129.084496
# 4     부산대역  35.230522  129.088694

# %%
coordinates = data[['위도','경도']].to_numpy()
place = fixdata['이름'].to_numpy()
print(coordinates[0])

# 중심좌표 설정(기본위치)
center_lat , center_lon =35.17574571, 129.0817409

#지도 생성
m = folium.Map(location = [center_lat, center_lon], zoom_start =12)
store_type = data['타입']

for i, (lat, lon) in enumerate(coordinates):
    if store_type[i] == "pin_generalDT":
        ccolor = "blue"
        fcolor = "skyblue"
    elif store_type[i] == "pin_general":
        ccolor = "green"
        fcolor = "yellow"
    else:
        ccolor = "red" 
        fcolor = "orange"
        
    folium.CircleMarker(
        location=[lat, lon],
        radious = 10,
        color = ccolor,
        fill = True,
        fill_color = fcolor,
        fill_opacity = 0.5,
        tooltip = place[i],
        popup=f"<b>{place[i]}</b><br>위도: {lat}<br>경도: {lon}" 
    ).add_to(m)  # 지도생성 후 원을 그리고 지도에 붙임


    folium.Marker(
        location=[lat+0.001,lon],
        icon = folium.DivIcon(f'<div style = "font-size : 9 px; color:black; background-color:white; width:50px; white-space:nowrap; overflow:hidden; text-overflow:ellipsis; opacty:0.7; border-radius:5px">{place[i]}</div>')
    ).add_to(m)

m
# Out:
# [ 35.26217863 129.09132504]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c850eb8452f628cc7ed35bc169bae499 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c850eb8452f628cc7ed35bc169bae499&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c850eb8452f628cc7ed35bc169bae499 = L.map(
#                 &quot;map_c850eb8452f628cc7ed35bc169bae499&quot;,
#                 {
#                     center: [35.17574571, 129.0817409],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_912cbb17ab11b824b27f8508762dccf5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_912cbb17ab11b824b27f8508762dccf5.addTo(map_c850eb8452f628cc7ed35bc169bae499);
#
#
#             var circle_marker_a42938778a1c7b5038d71cb6927f3679 = L.circleMarker(
#                 [35.2621786292157, 129.091325043351],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;skyblue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c850eb8452f628cc7ed35bc169bae499);
#
#
#         var popup_015a09b8eec325051cfbefb757c30458 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f1205acb31ec6b30f0918a85d0c4c5e2 = $(`&lt;div id=&quot;html_f1205acb31ec6b30f0918a85d0c4c5e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;금정남산동DT&lt;/b&gt;&lt;br&gt;위도: 35.2621786292157&lt;br&gt;경도: 129.091325043351&lt;/div&gt;`)[0];
#                 popup_015a09b8eec325051cfbefb757c30458.setContent(html_f1205acb31ec6b30f0918a85d0c4c5e2);
#
#
#
#         circle_marker_a42938778a1c7b5038d71cb6927f3679.bindPopup(popup_015a09b8eec325051cfbefb757c30458)
#         ;
#
#
#
#
#             circle_marker_a42938778a1c7b5038d71cb6927f3679.bindTooltip(
#                 `&lt;div&gt;
#                      금정남산동DT
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_8809b7996998c3f4f1a9340f47e7f691 = L.marker(
#                 [35.263178629215695, 129.091325043351],
#                 {
# }
#             ).addTo(map_c850eb8452f628cc7ed35bc169bae499);
#
#
#             var div_icon_6c542756920befa41f29778fc88e50bf = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style = \&quot;font-size : 9 px; color:black; background-color:white; width:50px; white-space:nowrap; overflow:hidden; text-overflow:ellipsis; opacty:0.7; border-radius:5px\&quot;\u003e\uae08\uc815\ub0a8\uc0b0\ub3d9DT\u003c/div\u003e&quot;,
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_8809b7996998c3f4f1a9340f47e7f691.setIcon(div_icon_6c542756920befa41f29778fc88e50bf);
#
#
#                 marker_8809b7996998c3f4f1a9340f47e7f691.setIcon(div_icon_6c542756920befa41f29778fc88e50bf);
#
#
#             var circle_marker_05a0822af3ef076700383cb61a87b7c3 = L.circleMarker(
#                 [35.2388135211636, 129.092985849499],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;skyblue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c850eb8452f628cc7ed35bc169bae499);
#
#
#         var popup_7cb42ef117673fe83f80c85c8c113ed2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a605f15490eb061e594e5b6244660d0 = $(`&lt;div id=&quot;html_3a605f15490eb061e594e5b6244660d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;금정구청DT&lt;/b&gt;&lt;br&gt;위도: 35.2388135211636&lt;br&gt;경도: 129.092985849499&lt;/div&gt;`)[0];
#                 popup_7cb42ef117673fe83f80c85c8c113ed2.setContent(html_3a605f15490eb061e594e5b6244660d0);
#
#
#
#         circle_marker_05a0822af3ef076700383cb61a87b7c3.bindPopup(popup_7cb42ef117673fe83f80c85c8c113ed2)
#         ;
#
#
#
#
#             circle_marker_05a0822af3ef076700383cb61a87b7c3.bindTooltip(
#                 `&lt;div&gt;
#                      금정구청DT
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_f4a33d7b6871f37985af2cf563d71279 = L
